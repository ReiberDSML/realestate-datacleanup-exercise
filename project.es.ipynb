# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
casa_mas_cara = ds.loc[ds['price'].idxmax()]


print (f"La casa con dirección en calle {casa_mas_cara['address']} es la más cara y su precio es de {casa_mas_cara['price']} USD")
# Out:
# La casa con dirección en calle El Escorial es la más cara y su precio es de 8500000 USD

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
casa_mas_barata = ds.loc[ds['price'].idxmin()]

print (f"La casa con dirección en calle {casa_mas_barata['address']} es la más barata y su precio es de {casa_mas_barata['price']} USD")
# Out:
# La casa con dirección en calle Parla es la más barata y su precio es de 0 USD

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
casa_mas_grande = ds.loc[ds['surface'].idxmax()]

casa_mas_pequena = ds.loc[ds['surface'].idxmin()]

print (f"La casa mas grande está en calle {casa_mas_grande['address']} y su superficie es de {casa_mas_grande['surface']} metros")
print (f"La casa mas pequeña está en calle {casa_mas_pequena['address']} y su superficie es de {casa_mas_pequena['surface']} metros")
# Out:
# La casa mas grande está en calle Sevilla la Nueva y su superficie es de 249000.0 metros
# La casa mas pequeña está en calle Calle Amparo,  Madrid Capital y su superficie es de 15.0 metros

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
poblaciones = ds.groupby('level5').size().count()

print(f'Número de poblaciones: {poblaciones}')
# Out:
# Número de poblaciones: 168

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
valores_nulos = ds.isna().any().any()

if valores_nulos:
    for col in ds.columns:
        if ds[col].isna().any():
            filas_nulas = ds[ds[col].isna()].index.tolist()
            print (f"La columna {col} contiene valores nulos en las filas {filas_nulas}")
# Out:
# La columna realEstate_name contiene valores nulos en las filas [803, 1190, 2104, 2907, 2908, 4969, 5246, 5958, 7192, 10585]
# ...

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
ds_original = ds.shape
print (f"El dataframe original mide: {ds_original}")

ds_sin_valores_nulos = ds.dropna(how='any')

ds_modificado = ds_sin_valores_nulos.shape
print (f"El dataframe modificado mide: {ds_modificado}")
# Out:
# El dataframe original mide: (15335, 37)
# El dataframe modificado mide: (0, 37)

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
arroyomolinos = ds[ds['level5'] == 'Arroyomolinos (Madrid)']

media_precios = arroyomolinos['price'].mean()

print (f" La media de precios en Arroyomolinos (Madrid) es {media_precios} USD")
# Out:
#  La media de precios en Arroyomolinos (Madrid) es 294541.59854014596 USD

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
plt.hist(arroyomolinos['price'])
plt.title('Precios en Arroyomolinos (Madrid)')
plt.xlabel('Precios')
plt.ylabel('Frecuencia')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Lo que vemos en el histograma es que el precio de la vivienda en Arroyomolinos (Madrid) se encuentra en el rango medio entre 200.000 y 400.000 euros

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
valdemorillo = ds[ds['level5'] == 'Valdemorillo']

galapagar = ds[ds['level5'] == 'Galapagar']

precios_valdemorillo = valdemorillo['price'].mean()
precios_galapagar = galapagar['price'].mean()

print (f"El precio medio de la vivienda en Valdemorillo es de {precios_valdemorillo} USD")
print (f"El precio medio de la vivienda en Galapagar es de {precios_galapagar} USD")
# Out:
# El precio medio de la vivienda en Valdemorillo es de 363860.2931034483 USD
# El precio medio de la vivienda en Galapagar es de 360063.20238095237 USD

# %% [markdown]
# El precio medio de la vivienda en Valdemorillo es ligeramente superior que en Galapagar, aunque la diferencia es mínima.

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
ds['pps'] = ds['price'] / ds['surface']

pps_valdemorillo = valdemorillo['pps']
pps_galapagar = galapagar['pps']

pps_mean_valdemorillo = pps_valdemorillo.mean()
pps_mean_galapagar = pps_galapagar.mean()

print (f"El precio medio por metro cuadrado en Valdemorillo es de {pps_mean_valdemorillo} USD/m2")
print (f"El precio medio por metro cuadrado en Galapagar es de {pps_mean_galapagar} USD/m2")
# Out:
# El precio medio por metro cuadrado en Valdemorillo es de 1317.9502109024986 USD/m2
# El precio medio por metro cuadrado en Galapagar es de 1606.3240303094024 USD/m2

# %% [markdown]
# El precio medio por metro cuadrado de la vivienda en Galapagar es un más caro que en Valdemorillo. Por lo que el acceso a la vivienda en Valdemorillo es más asequible económicamente

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
plt.scatter(ds['price'], ds['surface'])
plt.title('Relación superficie-precio de las casas')
plt.xlabel('Precios')
plt.ylabel('Superficie')
plt.show()

# %% [markdown]
# Según vemos en la gráfica el precio de las casa no depende de la superficie de la misma, ya que existen viviendas con "poca" superficie en todos el rango de precios. La inclusión de valores extremos en la gráfica imposibilita una visualizacion más exacta de los datos por lo que sería recomendable hacer una limpieza de estos datos para una mejor visualización de la gráfica.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
agencias = ds['realEstate_name'].nunique()

print(f"El dataset contiene {agencias} agencias de bienes raíces")
# Out:
# El dataset contiene 1821 agencias de bienes raíces

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
frecuencia_poblaciones = ds['level5'].value_counts()

poblacion_mas_casa = frecuencia_poblaciones.idxmax()
frecuencia_poblacion_mas_casas = frecuencia_poblaciones.max()

print(f"La población que más se repite es {poblacion_mas_casa} y se repite un total de {frecuencia_poblacion_mas_casas} veces")
# Out:
# La población que más se repite es  Madrid Capital y se repite un total de 6643 veces

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
ciudades = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón'] 

cinturon_sur_madrid = ds[ds['level5'].isin(ciudades)]

print (cinturon_sur_madrid)
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
mediana_poblacion = cinturon_sur_madrid.groupby('level5')['price'].median()

plt.bar(mediana_poblacion.index, mediana_poblacion.values)
plt.xlabel('Población')
plt.ylabel('Mediana de los precios')
plt.show()

# %% [markdown]
# Acorde con el gráfico podemos ver que en Getafe el precio de la vivienda es mucho más caro que en el resto de poblaciones. Siendo Fuenlabrada la población con los precios de vivienda mas bajos.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
media_precio = cinturon_sur_madrid['price'].mean()
var_precio = cinturon_sur_madrid['price'].var()

media_rooms = cinturon_sur_madrid['rooms'].mean()
var_rooms = cinturon_sur_madrid['rooms'].var()

media_surface = cinturon_sur_madrid['surface'].mean()
var_surface = cinturon_sur_madrid['surface'].var()

media_baths = cinturon_sur_madrid['bathrooms'].mean()
var_baths = cinturon_sur_madrid['bathrooms'].mean()

print (f"El precio medio de la vivienda en el cinturón sur de Madrid es de {media_precio} USD, teniendo una varianza de {var_precio}")
print (f"El número de habitaciones medio en el cinturón sur de Madrid es de {media_rooms}, teniendo una varianza de {var_rooms}")
print (f"La superficie media en el cinturón sur de Madrid es de {media_surface} m2, teniendo una varianza de {var_surface}")
print (f"El número de baños medio en el cinturón sur de Madrid es de {media_baths}, teniendo una varianza de {var_baths}")
# Out:
# El precio medio de la vivienda en el cinturón sur de Madrid es de 223094.48070562293 USD, teniendo una varianza de 14921367508.04902
# El número de habitaciones medio en el cinturón sur de Madrid es de 3.0177383592017737, teniendo una varianza de 0.7188858892927542
# La superficie media en el cinturón sur de Madrid es de 111.75222363405337 m2, teniendo una varianza de 4263.051760316337
# El número de baños medio en el cinturón sur de Madrid es de 1.633221850613155, teniendo una varianza de 1.633221850613155

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
casa_mas_cara_cinturon_sur = cinturon_sur_madrid.loc[cinturon_sur_madrid.groupby('level5')['price'].idxmax()]

ds_casa_mas_cara_cinturon_sur = casa_mas_cara_cinturon_sur[['level5', 'address', 'price']]

print (ds_casa_mas_cara_cinturon_sur)
# Out:
#             level5                                address    price
# 5585      Alcorcón                               Alcorcón   950000
# 11561  Fuenlabrada  Calle de Paulo Freire, 5, Fuenlabrada   490000
# 2881        Getafe                                 Getafe  1050000
# 10412      Leganés           Avenida Reina Sofía, Leganés   650000

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
def normalizar_precios(grupo):
    return (grupo - grupo.mean()) / grupo.std()

cinturon_sur_madrid.loc[:, 'precio_normalizado'] = cinturon_sur_madrid.groupby('level5')['price'].transform(normalizar_precios)

poblaciones = cinturon_sur_madrid['level5'].unique()

fig, axs = plt.subplots(2, 2, figsize=(10, 8))

for ax, poblacion in zip(axs.flatten(), poblaciones):
    ax.hist(cinturon_sur_madrid[cinturon_sur_madrid['level5'] == poblacion]['precio_normalizado'])
    ax.set_title(f'{poblacion}')


fig.text(0.5, 0.04, 'Precio normalizado', ha='center')
fig.text(0.04, 0.5, 'Frecuencia', va='center', rotation='vertical')

plt.tight_layout(rect=[0.05, 0.05, 0.95, 0.95])
plt.show()

# %% [markdown]
# Viendo las gráficas observamos que la mayoría presenta un pico entre el -1 y 0, esto quiere decir que la mayoría de precios de la vivienda suelen estar por debajo de la media. Getafe con una distribucion más dispersa indica que los precios presentan mayor variabilidad.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
getafe = cinturon_sur_madrid[cinturon_sur_madrid['level5'] == 'Getafe']
alcorcon = cinturon_sur_madrid[cinturon_sur_madrid['level5'] == 'Alcorcón']

media_pps_getafe = getafe ['pps'].mean()
media_pps_alcorcon = alcorcon['pps'].mean()

print (f"La media del precio por m2 en Alcorcón es de {media_pps_alcorcon} USD/m2")
print (f"La media del precio por m2 en Getafe es de {media_pps_getafe} USD/m2")
# Out:
# La media del precio por m2 en Alcorcón es de 2239.302480199618 USD/m2
# La media del precio por m2 en Getafe es de 2066.314949251463 USD/m2

# %% [markdown]
# Analizando la media de los precios por m2 de ambas poblaciones podemos decir que la vivienda en Alcorcón es ligeramente más cara que en Getafe

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

for ax, poblacion in zip(axs.flatten(), poblaciones):
    pps_madrid_sur = cinturon_sur_madrid[cinturon_sur_madrid['level5'] == poblacion]
    ax.scatter(pps_madrid_sur.index, pps_madrid_sur['pps'])
    ax.set_title(f'{poblacion}')


fig.text(0.04, 0.5, 'Precio por m2', va='center', rotation='vertical')

plt.tight_layout(rect=[0.05, 0.05, 0.95, 0.95])
plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, Marker, Icon, basemaps

# Mapa centrado en (60 grados latitud y -2.2 grados longitud)
# Latitud, longitud
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.OpenStreetMap.Mapnik)
map
# Out:
# Map(center=[60, -2.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
## Aquí: traza la coordenadas de los estados

## PON TU CÓDIGO AQUÍ:

coordenadas_dict = cinturon_sur_madrid.groupby('level5').apply(lambda x: [{'latitude': lat, 'longitude': lon} for lat, lon in zip(x['latitude'], x['longitude'])]).to_dict()

map = Map(center=(40.3, -3.8), zoom=10, basemap=basemaps.OpenStreetMap.Mapnik)

colores = {
    'Alcorcón': 'yellow',
    'Fuenlabrada': 'green',
    'Getafe': 'blue',
    'Leganés': 'red'
}

for poblacion, coordenadas in coordenadas_dict.items():
    for coord in coordenadas:
        icon = Icon(icon_url=f'http://maps.google.com/mapfiles/ms/icons/{colores.get(poblacion, "gray")}-dot.png', icon_size=[30, 30])
        marker = Marker(location=(coord['latitude'], coord['longitude']), draggable=False,icon=icon, title=poblacion)
        map.add_layer(marker)

map
# Out:
# /tmp/ipykernel_598/2739559222.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   coordenadas_dict = cinturon_sur_madrid.groupby('level5').apply(lambda x: [{'latitude': lat, 'longitude': lon} for lat, lon in zip(x['latitude'], x['longitude'])]).to_dict()
# Map(center=[40.3, -3.8], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out…
